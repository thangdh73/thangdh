# %%
# The code was removed by Watson Studio for sharing.
# Out:
#                   APA        HAL  JSE.L        OXY        SLB
# Date
# 2014-12-31  55.102455  34.972336    NaN  61.550159  70.723862
# 2015-01-02  56.122372  35.114594    NaN  61.580700  70.939148
# 2015-01-05  52.675724  34.421017    NaN  59.297672  69.018097
# 2015-01-06  52.104210  34.083126    NaN  58.793716  67.668335
# 2015-01-07  51.523899  34.999004    NaN  58.801357  67.660057

# %%
# Plot the data
df_data_0.plot(figsize=(16,8))

plt.ylabel('Share price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.legend()
plt.show()

# %%
# Plot all the close prices
((df_data_0['2020-02-01':'2020-04-30'][['SLB','JSE.L']].pct_change()+1).cumprod()).plot(figsize=(16, 7))

# Define the label for the title of the figure
plt.title("Returns from {} to {}".format( df_data_0.index[0],df_data_0.index[-1]), fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.legend()
plt.show()

# %%
# Calculate the daily percentage change for `daily_close_px`
daily_pct_change = df_data_0.pct_change()
daily_pct_change.plot(figsize=(16,8))

# Plot a scatter matrix with the `daily_pct_change` data 
scatter_matrix(daily_pct_change, diagonal='kde', alpha=0.1,figsize=(12,12))

# Show the resulting plot
plt.show()

# %%
# Define the minumum of periods to consider 
min_periods = 30 

# Calculate the volatility
vol = daily_pct_change['2019-06-01':][['SLB','JSE.L']].rolling(min_periods).std() * np.sqrt(252) 

# Plot the volatility
vol.plot(figsize=(16, 7))

# Define the label for the title of the figure and Show the plot
plt.title("Annulised Volatility {} days".format(min_periods), fontsize=16)
plt.show()
